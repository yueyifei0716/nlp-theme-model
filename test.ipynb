# %%
import pandas as pd

def read_csv_column(csv_path, column_name):
    df = pd.read_csv(csv_path, encoding='utf-8', low_memory=False)
    return df[column_name].tolist()


def read_csv_with_weight(csv_path):
    df = pd.read_csv(csv_path, encoding='utf-8', low_memory=False)

    # 转发数,评论数,点赞数
    comments = df['评论数'].tolist()
    reposts = df['转发数'].tolist()
    likes = df['点赞数'].tolist()
    weibos = df['微博正文'].tolist()
    results = []

    # for row in range(len(weibos)):
    #     if comments[row] + reposts[row] + likes[row] > 10:
    #         results.append(weibos[row])

    for row in range(len(weibos)):
        times = 1 + int(reposts[row]/100) + int(comments[row]/500) + int(likes[row]/1000)
        for time in range(times):
            results.append(weibos[row])

    new_list = []
    for result in results:
        result = result.split()
        new_list.append(result)

    return new_list

# %%
from gensim.corpora import Dictionary
from gensim.models import TfidfModel, LdaMulticore

# %%
trump_content = read_csv_with_weight('./trump/trump01.csv')

# %%
dictionary = Dictionary(trump_content)
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=3000)
bow_corpus = [dictionary.doc2bow(doc) for doc in trump_content]

# %%
tfidf = TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %%
lda_model_tfidf = LdaMulticore(corpus_tfidf, num_topics=30, id2word=dictionary, passes=10, workers=4)
lda_model_tfidf.save('./model/lda_models_tfidf_1.lda')

# %%
lda_model = LdaMulticore.load('./model/lda_models_tfidf_1.lda')
item = []
for j in range(len(trump_content)):
    item = item + trump_content[j]

bow_vector = dictionary.doc2bow(item)

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.10087643563747406	 Topic: 0.016*"普京" + 0.013*"中国" + 0.010*"美国" + 0.009*"电话" + 0.009*"披露" + 0.009*"亲信" + 0.009*"痛斥" + 0.008*"台湾" + 0.008*"错过" + 0.007*"商务"
# Score: 0.09863615781068802	 Topic: 0.034*"伊朗" + 0.021*"袭击" + 0.020*"伊拉克" + 0.020*"美军" + 0.018*"基地" + 0.015*"导弹" + 0.011*"军事" + 0.010*"美国" + 0.010*"战争" + 0.010*"空袭"
# Score: 0.07081770896911621	 Topic: 0.048*"伊朗" + 0.042*"声明" + 0.041*"领导人" + 0.040*"报复" + 0.036*"发表" + 0.032*"袭击" + 0.029*"严厉" + 0.027*"3日" + 0.027*"发动" + 0.025*"伊拉克"
# Score: 0.05953076854348183	 Topic: 0.051*"中国" + 0.038*"提供" + 0.030*"肺炎" + 0.025*"停止" + 0.022*"美方" + 0.022*"打压" + 0.021*"疫情" + 0.019*"英国" + 0.017*"企业" + 0.017*"外交部"
# Score: 0.05686280503869057	 Topic: 0.052*"女儿" + 0.041*"喊话" + 0.039*"孩子" + 0.036*"家人" + 0.036*"收尸" + 0.032*"美军" + 0.031*"苏莱曼尼" + 0.029*"葬礼" + 0.016*"伊朗" + 0.016*"领袖"
# Score: 0.05512788146734238	 Topic: 0.035*"参议院" + 0.034*"弹劾案" + 0.032*"弹劾" + 0.027*"审理" + 0.024*"审判" + 0.019*"正式" + 0.011*"投票" + 0.011*"时刻" + 0.011*"律师" + 0.010*"总统"
# Score: 0.05129767581820488	 Topic: 0.025*"黄金" + 0.016*"市场" + 0.012*"塔利班" + 0.012*"美元" + 0.012*"原油" + 0.011*"欧盟" + 0.011*"美联储" + 0.010*"经济" + 0.010*"英国" + 0.010*"股市"
# Score: 0.05023477226495743	 Topic: 0.032*"协议" + 0.024*"贸易" + 0.022*"签署" + 0.020*"协定" + 0.019*"阶段" + 0.015*"第一" + 0.011*"中国" + 0.011*"印度" + 0.011*"自由" + 0.010*"经贸"
# Score: 0.04530872404575348	 Topic: 0.017*"博尔顿" + 0.009*"川普" + 0.009*"美国" + 0.008*"男子" + 0.007*"移民" + 0.007*"被捕" + 0.007*"庄园" + 0.007*"总统" + 0.006*"政府" + 0.006*"爸爸"
# Score: 0.03602011874318123	 Topic: 0.032*"病毒" + 0.031*"疫情" + 0.029*"冠状" + 0.028*"新型" + 0.025*"应对" + 0.023*"控制" + 0.019*"巴勒斯坦" + 0.019*"计划" + 0.019*"方案" + 0.018*"中国"
# Score: 0.03130268305540085	 Topic: 0.033*"伊朗" + 0.020*"斩首" + 0.018*"暗杀" + 0.015*"苏莱曼尼" + 0.014*"伊拉克" + 0.012*"开战" + 0.012*"代价" + 0.012*"组织" + 0.012*"付出" + 0.011*"真的"
# Score: 0.03106042370200157	 Topic: 0.058*"达沃斯" + 0.038*"论坛" + 0.020*"环保" + 0.019*"演讲" + 0.018*"少女" + 0.018*"任正非" + 0.017*"世界" + 0.017*"经济" + 0.015*"出席" + 0.012*"宇宙"
# Score: 0.030240053310990334	 Topic: 0.029*"关税" + 0.014*"墨加" + 0.014*"进口" + 0.012*"布隆伯格" + 0.012*"财经" + 0.012*"频道" + 0.012*"汽车" + 0.012*"加征" + 0.012*"美联储" + 0.011*"总统"
# Score: 0.02332330495119095	 Topic: 0.022*"围观" + 0.021*"美军" + 0.019*"战争" + 0.016*"伊朗" + 0.013*"伊拉克" + 0.012*"说话" + 0.012*"韩国" + 0.012*"空袭" + 0.011*"受伤" + 0.011*"袭击"
# Score: 0.022153684869408607	 Topic: 0.024*"蹦迪" + 0.023*"白宫" + 0.023*"现场" + 0.014*"大学" + 0.013*"上演" + 0.012*"NCAA" + 0.012*"大型" + 0.012*"招待" + 0.012*"冠军" + 0.012*"球员们"
# Score: 0.021978599950671196	 Topic: 0.024*"去世" + 0.018*"苏莱曼尼" + 0.015*"伊朗" + 0.014*"细节" + 0.013*"克什米尔" + 0.013*"篮球" + 0.012*"完了" + 0.011*"洪水" + 0.011*"伊拉克" + 0.010*"杀死"
# Score: 0.021869324147701263	 Topic: 0.059*"苹果" + 0.034*"炮轰" + 0.023*"隐私" + 0.022*"财联社" + 0.021*"解锁" + 0.021*"提供者" + 0.020*"用户" + 0.019*"不堪" + 0.016*"放弃" + 0.014*"手机"
# Score: 0.019563257694244385	 Topic: 0.030*"航班" + 0.021*"抗击" + 0.020*"白宫" + 0.019*"暂停" + 0.019*"协助" + 0.018*"疫情" + 0.018*"边境" + 0.017*"全场" + 0.017*"中国" + 0.017*"遇难者"
# Score: 0.01870683580636978	 Topic: 0.030*"奥巴马" + 0.025*"悼念" + 0.021*"巨星" + 0.015*"发文" + 0.015*"索罗斯" + 0.015*"头条" + 0.015*"遇难" + 0.013*"文章" + 0.013*"希拉里" + 0.012*"白宫"
# Score: 0.018001005053520203	 Topic: 0.028*"伊朗" + 0.026*"分享" + 0.025*"永远" + 0.022*"核武器" + 0.022*"播放" + 0.020*"拥有" + 0.019*"伊核" + 0.017*"发推" + 0.016*"协议" + 0.014*"26日"
# Score: 0.01764783263206482	 Topic: 0.031*"病毒" + 0.030*"农历" + 0.028*"冠状" + 0.020*"击落" + 0.020*"武汉" + 0.020*"新型" + 0.019*"流感" + 0.017*"客机" + 0.017*"默哀" + 0.016*"乌克兰"
# Score: 0.01715737208724022	 Topic: 0.048*"努力" + 0.031*"中国" + 0.029*"欣赏" + 0.028*"遏制" + 0.028*"致敬" + 0.025*"解决" + 0.022*"透明性" + 0.022*"发推特" + 0.022*"马斯克" + 0.021*"天才"
# Score: 0.016592103987932205	 Topic: 0.037*"梅拉尼娅" + 0.025*"牵手" + 0.025*"杜特尔特" + 0.023*"新年" + 0.018*"夫人" + 0.017*"愿望" + 0.017*"搞笑" + 0.017*"邀请" + 0.015*"失败" + 0.014*"视频"
# Score: 0.016344008967280388	 Topic: 0.042*"弹劾" + 0.029*"佩洛西" + 0.026*"众议院" + 0.026*"条款" + 0.017*"议长" + 0.012*"提交" + 0.011*"总统" + 0.010*"吐槽" + 0.010*"朋友" + 0.010*"签字"
# Score: 0.016024602577090263	 Topic: 0.034*"名单" + 0.028*"支持" + 0.022*"赶走" + 0.018*"中国" + 0.016*"直播" + 0.014*"微博" + 0.014*"地图" + 0.012*"最新" + 0.012*"监测" + 0.011*"关注"
# Score: 0.013876771554350853	 Topic: 0.028*"修正案" + 0.025*"NBA" + 0.021*"地震" + 0.021*"13" + 0.017*"民主党" + 0.017*"被否" + 0.016*"大使馆" + 0.015*"11" + 0.014*"鏖战" + 0.014*"伊拉克"
# Score: 0.012936107814311981	 Topic: 0.210*"北约" + 0.176*"建议" + 0.164*"名字" + 0.147*"中东" + 0.014*"恶化" + 0.009*"富豪" + 0.009*"舞台" + 0.009*"10万" + 0.008*"作秀" + 0.008*"哔哩"
# Score: 0.011456036008894444	 Topic: 0.042*"人山人海" + 0.040*"一生" + 0.038*"邪恶" + 0.036*"势力" + 0.035*"摧毁" + 0.034*"意志" + 0.034*"西亚" + 0.034*"终结" + 0.034*"幻想" + 0.033*"跳梁"
